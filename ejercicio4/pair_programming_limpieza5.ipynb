# %%
from sklearn.impute import SimpleImputer
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.impute import KNNImputer

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('datos/bank_additional_edit3.csv', index_col = 0)

# %% [markdown]
# Es el momento de ponernos a trabajar con los valores nulos de nuevo 💪🏽. A lo largo de este ejercicio de pair programming vamos a intentar eliminar los valores nulos de nuestras columnas. En la lección hemos aprendido varios métodos de skelarn intentemos aplicarlos todos. Manos a la obra!
#
# Es el momento de eliminar los nulos:
#
#     1. Reemplazad los valores nulos del resto de las columnas categóricas por la moda, usando el método SimpleImputer.
# 💡 Pista 💡 La moda en este tipo de aproximación se indica como most_frequent.

# %%
df_cat = df.select_dtypes(include= 'object')
df_cat.head(2)
# Out:
#          job  marital    education default housing loan    contact  \
# 0  housemaid  married     basic 4y      No      No   No  telephone
# 1   services  married  high school     NaN      No   No  telephone
#
#       poutcome   y  month_day_week  month day_week
# 0  nonexistent  no  ['may', 'mon']  'may'    'mon'
# 1  nonexistent  no  ['may', 'mon']  'may'    'mon'

# %%
df_cat.isna().sum()*100/df_cat.shape[0]
# Out:
# job                0.811073
# marital            0.203983
# education          4.210782
# default           20.883924
# housing            2.413793
# loan               2.413793
# contact            0.009713
# poutcome           0.009713
# y                  0.009713
# month_day_week     0.009713
# month              0.009713
# day_week           0.009713
# dtype: float64

# %%
imputer = SimpleImputer(strategy='most_frequent', missing_values=np.nan)

# %%
df_cat.columns
# Out:
# Index(['job', 'marital', 'education', 'default', 'housing', 'loan', 'contact',
#        'poutcome', 'y', 'month_day_week', 'month', 'day_week'],
#       dtype='object')

# %%
imputer = imputer.fit(df[['job', 'marital', 'education', 'default', 'housing', 'loan', 'contact',
       'poutcome', 'y', 'month_day_week', 'month', 'day_week']])

# %%
df[['job', 'marital', 'education', 'default', 'housing', 'loan', 'contact',
       'poutcome', 'y', 'month_day_week', 'month', 'day_week']] = imputer.transform(df[['job', 'marital', 'education', 'default', 'housing', 'loan', 'contact',
       'poutcome', 'y', 'month_day_week', 'month', 'day_week']])

# %%
df.isnull().sum()
# Out:
# index             4
# age               2
# job               0
# marital           0
# education         0
# default           0
# housing           0
# loan              0
# contact           0
# duration          4
# campaign          4
# pdays             2
# previous          1
# poutcome          0
# emp,var,rate      4
# cons,price,idx    4
# cons,conf,idx     4
# euribor3m         4
# nr,employed       4
# y                 0
# month_day_week    0
# month             0
# day_week          0
# dtype: int64

# %%
df.head(2)
# Out:
#    index   age        job  marital    education default housing loan  \
# 0    0.0  56.0  housemaid  married     basic 4y      No      No   No
# 1    1.0  57.0   services  married  high school      No      No   No
#
#      contact  duration  ...     poutcome  emp,var,rate  cons,price,idx  \
# 0  telephone     261.0  ...  nonexistent           1.1          93.994
# 1  telephone     149.0  ...  nonexistent           1.1          93.994
#
#   cons,conf,idx  euribor3m  nr,employed   y  month_day_week  month day_week
# 0         -36.4      4.857       5191.0  no  ['may', 'mon']  'may'    'mon'
# 1         -36.4      4.857       5191.0  no  ['may', 'mon']  'may'    'mon'
#
# [2 rows x 23 columns]

# %% [markdown]
#     2. Utilizad el método Iterative Imputer para reemplazar todos los valores nulos de las columnas numéricas.

# %%
df['job'].unique()
# Out:
# array(['housemaid', 'services', 'administrative', 'blue-collar',
#        'technician', 'retired', 'management', 'unemployed',
#        'self-employed', 'entrepreneur', 'student'], dtype=object)

# %%
def eliminar_nulos_iterative(dataframe_completo):
    dataframe_num = dataframe_completo.select_dtypes(include = np.number)
    display(dataframe_num)
    imputer = IterativeImputer(n_nearest_features=None, imputation_order='ascending')
    imputer.fit(dataframe_num)
    numericas_trans = pd.DataFrame(imputer.transform(dataframe_num), columns = dataframe_num.columns)

    dataframe_completo.drop(dataframe_num.columns, axis = 1, inplace= True)
    dataframe_completo[numericas_trans.columns] = numericas_trans[numericas_trans.columns]
    # dataframe_completo = pd.concat([dataframe_completo, numericas_trans], axis = 1)
    
    return dataframe_completo

# %%
df.isnull().sum()
# Out:
# index             4
# age               2
# job               0
# marital           0
# education         0
# default           0
# housing           0
# loan              0
# contact           0
# duration          4
# campaign          4
# pdays             2
# previous          1
# poutcome          0
# emp,var,rate      4
# cons,price,idx    4
# cons,conf,idx     4
# euribor3m         4
# nr,employed       4
# y                 0
# month_day_week    0
# month             0
# day_week          0
# dtype: int64

# %%
eliminar_nulos_iterative(df)
# Out:
#          index   age  duration  campaign  pdays  previous  emp,var,rate  \
# 0          0.0  56.0     261.0       1.0  999.0       0.0           1.1
# 1          1.0  57.0     149.0       1.0  999.0       0.0           1.1
# 2          2.0  37.0     226.0       1.0  999.0       0.0           1.1
# 3          3.0  40.0     151.0       1.0  999.0       0.0           1.1
# 4          4.0  56.0     307.0       1.0  999.0       0.0           1.1
# ...        ...   ...       ...       ...    ...       ...           ...
# 41175  41187.0  74.0     239.0       3.0  999.0       0.0          -1.1
# 41183      NaN  38.0       NaN       NaN    NaN       NaN           NaN
# 41187      NaN  38.0       NaN       NaN    NaN       0.0           NaN
# 41178      NaN   NaN       NaN       NaN  999.0       0.0           NaN
# 41182      NaN   NaN       NaN       NaN  999.0       0.0           NaN
#
#        cons,price,idx  cons,conf,idx  euribor3m  nr,employed
# 0              93.994          -36.4      4.857       5191.0
# 1              93.994          -36.4      4.857       5191.0
# 2              93.994          -36.4      4.857       5191.0
# 3              93.994          -36.4      4.857       5191.0
# 4              93.994          -36.4      4.857       5191.0
# ...               ...            ...        ...          ...
# 41175          94.767          -50.8      1.028       4963.6
# 41183             NaN            NaN        NaN          NaN
# 41187             NaN            NaN        NaN          NaN
# 41178             NaN            NaN        NaN          NaN
# 41182             NaN            NaN        NaN          NaN
#
# [41180 rows x 11 columns]
#                   job  marital            education default housing loan  \
# 0           housemaid  married             basic 4y      No      No   No
# 1            services  married          high school      No      No   No
# 2            services  married          high school      No      Si   No
# 3      administrative  married             basic 6y      No      No   No
# 4            services  married          high school      No      No   Si
# ...               ...      ...                  ...     ...     ...  ...
# 41175         retired  married  professional course      No      Si   No
# 41183  administrative  married    university degree      No      Si   No
# 41187  administrative  married    university degree      No      Si   No
# 41178  administrative  married    university degree      No      Si   No
# 41182  administrative  married    university degree      No      Si   No
#
#          contact     poutcome   y  month_day_week  ...        age    duration  \
# 0      telephone  nonexistent  no  ['may', 'mon']  ...  56.000000  261.000000
# 1      telephone  nonexistent  no  ['may', 'mon']  ...  57.000000  149.000000
# 2      telephone  nonexistent  no  ['may', 'mon']  ...  37.000000  226.000000
# 3      telephone  nonexistent  no  ['may', 'mon']  ...  40.000000  151.000000
# 4      telephone  nonexistent  no  ['may', 'mon']  ...  56.000000  307.000000
# ...          ...          ...  ..             ...  ...        ...         ...
# 41175   cellular      failure  no  ['nov', 'fri']  ...  74.000000  239.000000
# 41183   cellular  nonexistent  no  ['may', 'wed']  ...        NaN         NaN
# 41187   cellular  nonexistent  no  ['may', 'wed']  ...        NaN         NaN
# 41178   cellular  nonexistent  no  ['may', 'wed']  ...  39.890135  249.599504
# 41182   cellular  nonexistent  no  ['may', 'wed']  ...        NaN         NaN
#
#        campaign  pdays  previous  emp,var,rate  cons,price,idx  cons,conf,idx  \
# 0      1.000000  999.0       0.0      1.100000       93.994000      -36.40000
# 1      1.000000  999.0       0.0      1.100000       93.994000      -36.40000
# 2      1.000000  999.0       0.0      1.100000       93.994000      -36.40000
# 3      1.000000  999.0       0.0      1.100000       93.994000      -36.40000
# 4      1.000000  999.0       0.0      1.100000       93.994000      -36.40000
# ...         ...    ...       ...           ...             ...            ...
# 41175  3.000000  999.0       0.0     -1.100000       94.767000      -50.80000
# 41183       NaN    NaN       NaN           NaN             NaN            NaN
# 41187       NaN    NaN       NaN           NaN             NaN            NaN
# 41178  2.451745  999.0       0.0      0.083829       93.574105      -40.69256
# 41182       NaN    NaN       NaN           NaN             NaN            NaN
#
#        euribor3m  nr,employed
# 0       4.857000   5191.00000
# 1       4.857000   5191.00000
# 2       4.857000   5191.00000
# 3       4.857000   5191.00000
# 4       4.857000   5191.00000
# ...          ...          ...
# 41175   1.028000   4963.60000
# 41183        NaN          NaN
# 41187        NaN          NaN
# 41178   3.623976   5167.59094
# 41182        NaN          NaN
#
# [41180 rows x 23 columns]

# %%
df.isnull().sum()
# Out:
# job               0
# marital           0
# education         0
# default           0
# housing           0
# loan              0
# contact           0
# poutcome          0
# y                 0
# month_day_week    0
# month             0
# day_week          0
# index             3
# age               3
# duration          3
# campaign          3
# pdays             3
# previous          3
# emp,var,rate      3
# cons,price,idx    3
# cons,conf,idx     3
# euribor3m         3
# nr,employed       3
# dtype: int64

# %%
df.dtypes
# Out:
# job                object
# marital            object
# education          object
# default            object
# housing            object
# loan               object
# contact            object
# poutcome           object
# y                  object
# month_day_week     object
# month              object
# day_week           object
# index             float64
# age               float64
# duration          float64
# campaign          float64
# pdays             float64
# previous          float64
# emp,var,rate      float64
# cons,price,idx    float64
# cons,conf,idx     float64
# euribor3m         float64
# nr,employed       float64
# dtype: object

# %% [markdown]
#     3. Reemplazad los valores nulos de la columna age por la media de la edad usando el método KNN Imputer.

# %%
df_edad = df["age"].reset_index()
df_edad
# Out:
#        index        age
# 0          0  56.000000
# 1          1  57.000000
# 2          2  37.000000
# 3          3  40.000000
# 4          4  56.000000
# ...      ...        ...
# 41175  41175  74.000000
# 41176  41183        NaN
# 41177  41187        NaN
# 41178  41178  39.890135
# 41179  41182        NaN
#
# [41180 rows x 2 columns]

# %%
imputerknn = KNNImputer(n_neighbors = 5)
imputerknn.fit(df['age'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [22], line 2
#       1 imputerknn = KNNImputer(n_neighbors = 5)
# ----> 2 imputerknn.fit(df['age'])
#
# File ~/anaconda3/envs/adalabenv/lib/python3.10/site-packages/sklearn/impute/_knn.py:210, in KNNImputer.fit(self, X, y)
#     205 if self.n_neighbors <= 0:
#     206     raise ValueError(
#     207         "Expected n_neighbors > 0. Got {}".format(self.n_neighbors)
#     208     )
# --> 210 X = self._validate_data(
#     211     X,
#     212     accept_sparse=False,
#     213     dtype=FLOAT_DTYPES,
#     214     force_all_finite=force_all_finite,
#     215     copy=self.copy,
#     216 )
#     218 _check_weights(self.weights)
#     219 self._fit_X = X
#
# File ~/anaconda3/envs/adalabenv/lib/python3.10/site-packages/sklearn/base.py:577, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, **check_params)
#     575     raise ValueError("Validation should be done on X, y or both.")
#     576 elif not no_val_X and no_val_y:
# --> 577     X = check_array(X, input_name="X", **check_params)
#     578     out = X
#     579 elif no_val_X and not no_val_y:
#
# File ~/anaconda3/envs/adalabenv/lib/python3.10/site-packages/sklearn/utils/validation.py:879, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     877     # If input is 1D raise error
#     878     if array.ndim == 1:
# --> 879         raise ValueError(
#     880             "Expected 2D array, got 1D array instead:\narray={}.\n"
#     881             "Reshape your data either using array.reshape(-1, 1) if "
#     882             "your data has a single feature or array.reshape(1, -1) "
#     883             "if it contains a single sample.".format(array)
#     884         )
#     886 if dtype_numeric and array.dtype.kind in "USV":
#     887     raise ValueError(
#     888         "dtype='numeric' is not compatible with arrays of bytes/strings."
#     889         "Convert your data to numeric values explicitly instead."
#     890     )
#
# ValueError: Expected 2D array, got 1D array instead:
# array=[56.         57.         37.         ...         nan 39.89013464
#          nan].
# Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.

# %% [markdown]
#     4. Reemplazad los valores nulos de la columna age por la media de la edad usando el método Simple Imputer.

# %% [markdown]
#     5. ¿Podríais explicar qué diferencia hay entre estos últimos tres ejercicios?

# %% [markdown]
#     6. Guardad el csv.
